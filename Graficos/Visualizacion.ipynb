# %% [markdown]
# ## Importamos las librerías necesarias

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Formas de visualización de datos

# %% [markdown]
# ![Image of Yaktocat](https://martinnormark.com/content/images/size/w1600/2020/10/2VmgDnF.png)

# %%
#galeria de los graficos de la libreria
https://seaborn.pydata.org/examples/index.html

# %%
df = pd.read_csv('data.csv',index_col=0)

# %%
df.shape
# Out:
# (18207, 88)

# %%
list(df.columns)
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# # Trends

# %%
df['Joined'] = pd.to_datetime(df['Joined'])
df = df.sort_values(by = 'Joined')
df.head()
# Out:
#            ID            Name  Age  \
# 4741   140029        O. Pérez   45
# 7221   140181     H. Sogahata   38
# 10534  140180    M. Ogasawara   39
# 9570   168879  M. Al Shalhoub   37
# 10545  140183     S. Narazaki   42
#
#                                                 Photo   Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png        Mexico
# 7221   https://cdn.sofifa.org/players/4/19/140181.png         Japan
# 10534  https://cdn.sofifa.org/players/4/19/140180.png         Japan
# 9570   https://cdn.sofifa.org/players/4/19/168879.png  Saudi Arabia
# 10545  https://cdn.sofifa.org/players/4/19/140183.png         Japan
#
#                                        Flag  Overall  Potential  \
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# 7221   https://cdn.sofifa.org/flags/163.png       68         68
# 10534  https://cdn.sofifa.org/flags/163.png       65         65
# 9570   https://cdn.sofifa.org/flags/183.png       66         66
# ...

# %%
df.Wage.unique()
# Out:
# array(['8', '3', '2', '1', '4', '6', '10', '80', '23', '7', '37', '13',
#        '5', '565', '66', '11', '215', '40', '39', '9', '380', '18', '20',
#        '38', '21', '285', '47', '33', '72', '125', '92', '16', '27', '53',
#        '24', '74', '51', '12', '34', '130', '43', '22', '14', '31', '25',
#        '240', '15', '35', '135', '170', '315', '26', '19', '97', '120',
#        '48', '68', '32', '44', '82', '110', '36', '28', '73', '165',
#        '205', '42', '61', '29', '57', '17', '46', '140', '115', '52',
#        '180', '88', '95', '30', '78', '41', '76', '260', '49', '210',
#        '300', '58', '99', '55', '70', '50', '96', '91', '100', '155',
#        '250', '340', '150', '420', '175', '105', '94', '63', '185', '77',
#        '81', '45', '98', '200', '90', '190', '355', '160', '56', '59',
#        '85', '60', '54', '455', '62', '87', '145', '83', '195', '84',
#        '65', '67', '75', '69', '86', '64', '225', '71', '79', '93', '255',
# ...

# %%
## quitamos los simbolos para trasnformarlas ne numericas y poder multiplcarlas
##wage hay que multiplicarla por mil 
df['Wage'] = df.Wage.replace('\€|K', '', regex=True)
df['Wage'] = df['Wage'].astype('int')
df['Wage'] = df['Wage'] * 1000

# %%
df.Wage.unique()
# Out:
# array([  8000,   3000,   2000,   1000,   4000,   6000,  10000,  80000,
#         23000,   7000,  37000,  13000,   5000, 565000,  66000,  11000,
#        215000,  40000,  39000,   9000, 380000,  18000,  38000,  20000,
#        285000,  21000,  47000,  33000,  72000, 125000,  92000,  16000,
#         27000,  53000,  24000,  74000,  12000,  51000,  34000, 130000,
#         35000,  15000, 240000,  25000,  31000,  14000,  22000,  43000,
#        135000, 170000, 315000,  26000,  19000,  97000, 120000,  32000,
#         68000,  48000,  44000,  82000, 110000,  36000,  28000,  42000,
#         61000,  29000,  57000,  17000,  46000, 140000, 205000,  73000,
#        165000, 115000,  52000, 180000,  88000,  95000,  30000,  41000,
#         78000,  49000, 260000, 210000,  76000, 300000,  58000,  99000,
#         55000,  70000,  50000,  96000, 340000, 250000, 155000, 100000,
#         91000, 420000, 150000, 175000, 105000,  94000,  45000,  63000,
# ...

# %%
# supongamos que queremos ver el promedio de los salarios por año, tenemos que armar una variable del año de la fecha que se unio el jugador y dps
# sacar promedio por año
df['year_joined'] = df['Joined'].dt.year
# hay años con Nan esos los sacamos
df = df[~(df.year_joined.isna())]
df1 = df[df.Club.isin([])]
df1 = df.groupby('year_joined').agg({'Wage':'mean'}).reset_index()
sns.lineplot(data=df1, x="year_joined", y="Wage")
# Out:
# <AxesSubplot:xlabel='year_joined', ylabel='Wage'>

# %%
# supongamos que ahora queremos lo mismo pero abierto por club, pero seleccionamos algunos xq son muchos
df1 = df[df.Club.isin(['FC Barcelona', 'Real Madrid', 'Leicester City', 'Napoli', 'Arsenal'])]
df1 = df1.groupby(['year_joined','Club']).agg({'Wage':'mean'}).reset_index()
sns.lineplot(data=df1, x="year_joined", y="Wage", hue="Club")
# Out:
# <AxesSubplot:xlabel='year_joined', ylabel='Wage'>

# %% [markdown]
# # Distribution

# %%
#Ahora nos preguntamos cual es a distribucion de las edad de los jugadores cuando se unen a un club
sns.distplot(df['Age'])
# Out:
# C:\Users\Tatiana.Badaracco\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Relationship

# %%
## scaterplot
## si se quiere ver la correlacion entre dos variables, por ejemplo entre la edad del jugador y el salario
sns.scatterplot(x="Age", y="Wage",
                #palette="ch:r=-.2,d=.3_r",
                #hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-e4f6db9668f9> in <module>
#       1 ## scaterplot
#       2 ## si se quiere ver la correlacion entre dos variables, por ejemplo entre la edad del jugador y el salario
# ----> 3 sns.scatterplot(x="Age", y="Wage",
#       4                 hue="clarity", size="depth",
#       5                 #palette="ch:r=-.2,d=.3_r",
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
