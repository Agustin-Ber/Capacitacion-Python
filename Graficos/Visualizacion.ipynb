# %% [markdown]
# ## Importamos las librerías necesarias

# %% [markdown]
# Hay muchas librerías conocidas en python para trabajar con pandas. Entre ellas Plotly, Matplotlib y Seaborn. La elección de la librería depende en que esta trabajando y con cual uno se siente más cómodo.

# %% [markdown]
# Nosotros elegimos para este curso la librería seaborn.
# https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ## Formas de visualización de datos

# %% [markdown]
# ![Image of Yaktocat](https://martinnormark.com/content/images/size/w1600/2020/10/2VmgDnF.png)

# %% [markdown]
# La elección de que gráfica hacer depende de que se quiere ver.
# Vamos a trabajar con un dataset de la FIFA.

# %%
#importamos las librerias que vamos a utilizar
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data.csv',index_col=0)

# %%
df.shape
# Out:
# (18207, 88)

# %%
list(df.columns)
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
#  'Release Clause']

# %%
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo    Value  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png     €72M
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png    €102M
#
#     Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  €565K     2202           Left                       5.0        4.0
# 1  €405K     2228          Right                       5.0        4.0
# 2  €290K     2143          Right                       5.0        5.0
# 3  €260K     1471          Right                       4.0        3.0
# 4  €355K     2281          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Real Face Position  Jersey Number  \
# 0          4.0  Medium/ Medium       Messi       Yes       RF           10.0
# 1          5.0       High/ Low  C. Ronaldo       Yes       ST            7.0
# 2          5.0    High/ Medium      Neymar       Yes       LW           10.0
# 3          1.0  Medium/ Medium        Lean       Yes       GK            1.0
# 4          4.0      High/ High      Normal       Yes      RCM            7.0
#
#          Joined Loaned From Contract Valid Until Height  Weight    LS    ST  \
# 0   Jul 1, 2004         NaN                 2021    5'7  159lbs  88+2  88+2
# 1  Jul 10, 2018         NaN                 2022    6'2  183lbs  91+3  91+3
# 2   Aug 3, 2017         NaN                 2022    5'9  150lbs  84+3  84+3
# 3   Jul 1, 2011         NaN                 2020    6'4  168lbs   NaN   NaN
# 4  Aug 30, 2015         NaN                 2023   5'11  154lbs  82+3  82+3
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2
# 1  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  88+3  81+3  81+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
#
#     RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 0  84+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2
# 1  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  81+3  88+3  65+3  60+3  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0      84.0       95.0             70.0          90.0     86.0       97.0
# 1      84.0       94.0             89.0          81.0     87.0       88.0
# 2      79.0       87.0             62.0          84.0     84.0       96.0
# 3      17.0       13.0             21.0          50.0     13.0       18.0
# 4      93.0       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0   93.0        94.0         87.0         96.0          91.0         86.0
# 1   81.0        76.0         77.0         94.0          89.0         91.0
# 2   88.0        87.0         78.0         95.0          94.0         90.0
# 3   21.0        19.0         51.0         42.0          57.0         58.0
# 4   85.0        83.0         91.0         91.0          78.0         76.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0     91.0       95.0     95.0       85.0     68.0     72.0      59.0
# 1     87.0       96.0     70.0       95.0     95.0     88.0      79.0
# 2     96.0       94.0     84.0       80.0     61.0     81.0      49.0
# 3     60.0       90.0     43.0       31.0     67.0     43.0      64.0
# 4     79.0       91.0     77.0       91.0     63.0     90.0      75.0
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0       94.0        48.0           22.0         94.0    94.0       75.0
# 1       93.0        63.0           29.0         95.0    82.0       85.0
# 2       82.0        56.0           36.0         89.0    87.0       81.0
# 3       12.0        38.0           30.0         12.0    68.0       40.0
# 4       91.0        76.0           61.0         87.0    94.0       79.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0       96.0     33.0            28.0           26.0       6.0        11.0
# 1       95.0     28.0            31.0           23.0       7.0        11.0
# 2       94.0     27.0            24.0           33.0       9.0         9.0
# 3       68.0     15.0            21.0           13.0      90.0        85.0
# 4       88.0     68.0            58.0           51.0      15.0        13.0
#
#    GKKicking  GKPositioning  GKReflexes Release Clause
# 0       15.0           14.0         8.0        €226.5M
# 1       15.0           14.0        11.0        €127.1M
# 2       15.0           15.0        11.0        €228.1M
# 3       87.0           88.0        94.0        €138.6M
# 4        5.0           10.0        13.0        €196.4M

# %% [markdown]
# # Trends

# %% [markdown]
# Supongamos que queremos ver si el promedio de los sueldos varian por año. La variable tiempo que vamos a considerar es Joined que es la fecha cuando el jugador se unió a un club, y para ver el sueldo promedio deberíamos promediar por cada año la variable wage.

# %%
df['Joined'] = pd.to_datetime(df['Joined'])
df = df.sort_values(by = 'Joined')
df.head()
# Out:
#            ID            Name  Age  \
# 4741   140029        O. Pérez   45
# 7221   140181     H. Sogahata   38
# 10534  140180    M. Ogasawara   39
# 9570   168879  M. Al Shalhoub   37
# 10545  140183     S. Narazaki   42
#
#                                                 Photo   Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png        Mexico
# 7221   https://cdn.sofifa.org/players/4/19/140181.png         Japan
# 10534  https://cdn.sofifa.org/players/4/19/140180.png         Japan
# 9570   https://cdn.sofifa.org/players/4/19/168879.png  Saudi Arabia
# 10545  https://cdn.sofifa.org/players/4/19/140183.png         Japan
#
#                                        Flag  Overall  Potential  \
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# 7221   https://cdn.sofifa.org/flags/163.png       68         68
# 10534  https://cdn.sofifa.org/flags/163.png       65         65
# 9570   https://cdn.sofifa.org/flags/183.png       66         66
# 10545  https://cdn.sofifa.org/flags/163.png       65         65
#
#                   Club                                        Club Logo  \
# 4741           Pachuca  https://cdn.sofifa.org/teams/2/light/110147.png
# 7221   Kashima Antlers  https://cdn.sofifa.org/teams/2/light/101147.png
# 10534  Kashima Antlers  https://cdn.sofifa.org/teams/2/light/101147.png
# 9570          Al Hilal     https://cdn.sofifa.org/teams/2/light/605.png
# 10545   Nagoya Grampus  https://cdn.sofifa.org/teams/2/light/112092.png
#
#        Value Wage  Special Preferred Foot  International Reputation  \
# 4741   €160K  €8K     1256          Right                       2.0
# 7221    €60K  €3K      981          Right                       1.0
# 10534   €40K  €2K     1696          Right                       2.0
# 9570   €220K  €8K     1626           Left                       1.0
# 10545   €40K  €1K     1296          Right                       2.0
#
#        Weak Foot  Skill Moves       Work Rate Body Type Real Face Position  \
# 4741         3.0          1.0  Medium/ Medium    Stocky        No       GK
# 7221         3.0          1.0  Medium/ Medium    Normal        No       GK
# 10534        4.0          2.0  Medium/ Medium      Lean        No      CDM
# 9570         3.0          3.0     Medium/ Low    Normal        No      CAM
# 10545        3.0          1.0  Medium/ Medium    Normal        No       GK
#
#        Jersey Number     Joined Loaned From Contract Valid Until Height  \
# 4741            21.0 1991-06-01         NaN                 2021    5'8
# 7221            21.0 1998-01-01         NaN                 2021    6'2
# 10534           40.0 1998-01-01         NaN                 2021    5'8
# 9570            10.0 1998-07-01         NaN                 2019    5'4
# 10545            1.0 1999-01-01         NaN                 2021    6'2
#
#        Weight    LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# 4741   165lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7221   176lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10534  159lbs  54+2  54+2  54+2  56+2  56+2  56+2  56+2  56+2  59+2  59+2
# 9570   146lbs  58+2  58+2  58+2  62+2  62+2  62+2  62+2  62+2  65+2  65+2
# 10545  176lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         RAM    LM   LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB    LB  \
# 4741    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7221    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10534  59+2  57+2  63+2  63+2  63+2  57+2  59+2  64+2  64+2  64+2  59+2  58+2
# 9570   65+2  61+2  62+2  62+2  62+2  61+2  48+2  50+2  50+2  50+2  48+2  44+2
# 10545   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         LCB    CB   RCB    RB  Crossing  Finishing  HeadingAccuracy  \
# 4741    NaN   NaN   NaN   NaN      19.0       14.0             24.0
# 7221    NaN   NaN   NaN   NaN      13.0       12.0             18.0
# 10534  61+2  61+2  61+2  58+2      63.0       40.0             51.0
# 9570   41+2  41+2  41+2  44+2      73.0       62.0             44.0
# 10545   NaN   NaN   NaN   NaN      23.0       11.0             23.0
#
#        ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 4741           26.0     13.0       12.0   12.0        20.0         27.0
# 7221           26.0     18.0       14.0   10.0        11.0         33.0
# 10534          69.0     50.0       60.0   67.0        67.0         68.0
# 9570           73.0     62.0       64.0   69.0        69.0         72.0
# 10545          29.0     19.0       30.0   22.0        40.0         28.0
#
#        BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 4741          23.0          60.0         57.0     69.0       72.0     69.0
# 7221          16.0          17.0         19.0     28.0       52.0     32.0
# 10534         70.0          32.0         31.0     57.0       62.0     65.0
# 9570          67.0          33.0         39.0     62.0       62.0     68.0
# 10545         30.0          52.0         56.0     55.0       65.0     62.0
#
#        ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 4741        24.0     85.0     41.0      66.0       18.0        26.0
# 7221        21.0     52.0     37.0      51.0       15.0        21.0
# 10534       64.0     58.0     45.0      55.0       61.0        74.0
# 9570        67.0     60.0     30.0      35.0       64.0        31.0
# 10545       40.0     65.0     40.0      65.0       18.0        30.0
#
#        Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 4741            12.0         12.0    40.0       23.0       62.0     23.0
# 7221            12.0         10.0    45.0       12.0       20.0     17.0
# 10534           66.0         56.0    60.0       66.0       62.0     66.0
# 9570            36.0         66.0    71.0       75.0       65.0     62.0
# 10545           14.0         12.0    64.0       11.0       45.0     27.0
#
#        StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 4741             12.0           11.0      70.0        64.0       65.0
# 7221             12.0           13.0      69.0        66.0       68.0
# 10534            62.0           60.0       8.0        12.0       14.0
# 9570             21.0           21.0      12.0        16.0       12.0
# 10545            24.0           22.0      64.0        63.0       62.0
#
#        GKPositioning  GKReflexes Release Clause
# 4741            73.0        74.0          €272K
# 7221            68.0        73.0           €78K
# 10534            7.0        10.0           €52K
# 9570            15.0        13.0          €374K
# 10545           67.0        63.0           €50K

# %% [markdown]
# Si observamos la variable wage vemos que no es númerica, por lo tanto, no vamos a poder obtener un promedio. Deberíamos eliminar todo lo NO númerico.

# %%
df.Wage.unique()
# Out:
# array(['€8K', '€3K', '€2K', '€1K', '€4K', '€6K', '€10K', '€80K', '€23K',
#        '€7K', '€37K', '€13K', '€5K', '€565K', '€66K', '€11K', '€215K',
#        '€40K', '€39K', '€9K', '€380K', '€18K', '€38K', '€20K', '€285K',
#        '€21K', '€47K', '€33K', '€72K', '€125K', '€92K', '€16K', '€27K',
#        '€53K', '€24K', '€74K', '€12K', '€51K', '€34K', '€130K', '€35K',
#        '€15K', '€240K', '€25K', '€31K', '€14K', '€22K', '€43K', '€135K',
#        '€170K', '€315K', '€26K', '€19K', '€97K', '€120K', '€32K', '€68K',
#        '€48K', '€44K', '€82K', '€110K', '€36K', '€28K', '€42K', '€61K',
#        '€29K', '€57K', '€17K', '€46K', '€140K', '€205K', '€73K', '€165K',
#        '€115K', '€52K', '€180K', '€88K', '€95K', '€30K', '€41K', '€78K',
#        '€49K', '€260K', '€210K', '€76K', '€300K', '€58K', '€99K', '€55K',
#        '€70K', '€50K', '€96K', '€340K', '€250K', '€155K', '€100K', '€91K',
#        '€420K', '€150K', '€175K', '€105K', '€94K', '€45K', '€63K', '€81K',
#        '€185K', '€77K', '€98K', '€200K', '€90K', '€190K', '€355K',
#        '€160K', '€56K', '€85K', '€59K', '€60K', '€54K', '€455K', '€62K',
#        '€87K', '€145K', '€83K', '€195K', '€84K', '€65K', '€67K', '€75K',
#        '€69K', '€64K', '€86K', '€225K', '€71K', '€79K', '€93K', '€89K',
#        '€255K', '€230K', '€290K', '€265K', '€405K', '€245K', '€235K',
#        '€0'], dtype=object)

# %%
## quitamos los simbolos para trasnformarlas en numerica y poder multiplcarla
##wage hay que multiplicarla por mil que es lo que representa el K.
df['Wage'] = df.Wage.replace('\€|K', '', regex=True)
df['Wage'] = df['Wage'].astype('int')
df['Wage'] = df['Wage'] * 1000

# %%
df.Wage.unique()
# Out:
# array([  8000,   3000,   2000,   1000,   4000,   6000,  10000,  80000,
#         23000,   7000,  37000,  13000,   5000, 565000,  66000,  11000,
#        215000,  40000,  39000,   9000, 380000,  18000,  38000,  20000,
#        285000,  21000,  47000,  33000,  72000, 125000,  92000,  16000,
#         27000,  53000,  24000,  74000,  12000,  51000,  34000, 130000,
#         35000,  15000, 240000,  25000,  31000,  14000,  22000,  43000,
#        135000, 170000, 315000,  26000,  19000,  97000, 120000,  32000,
#         68000,  48000,  44000,  82000, 110000,  36000,  28000,  42000,
#         61000,  29000,  57000,  17000,  46000, 140000, 205000,  73000,
#        165000, 115000,  52000, 180000,  88000,  95000,  30000,  41000,
#         78000,  49000, 260000, 210000,  76000, 300000,  58000,  99000,
#         55000,  70000,  50000,  96000, 340000, 250000, 155000, 100000,
#         91000, 420000, 150000, 175000, 105000,  94000,  45000,  63000,
#         81000, 185000,  77000,  98000, 200000,  90000, 190000, 355000,
#        160000,  56000,  85000,  59000,  60000,  54000, 455000,  62000,
#         87000, 145000,  83000, 195000,  84000,  65000,  67000,  75000,
#         69000,  64000,  86000, 225000,  71000,  79000,  93000,  89000,
#        255000, 230000, 290000, 265000, 405000, 245000, 235000,      0])

# %% [markdown]
#  Para ver el promedio de los salarios por año, tenemos que armar una variable del año de la fecha que se unio el jugador y después sacar promedio por año.

# %%
df['year_joined'] = df['Joined'].dt.year
# hay años con Nan esos los sacamos
df = df[~(df.year_joined.isna())]
df1 = df[df.Club.isin([])]
df1 = df.groupby('year_joined').agg({'Wage':'mean'}).reset_index()
sns.lineplot(data=df1, x="year_joined", y="Wage")
# Out:
# <AxesSubplot:xlabel='year_joined', ylabel='Wage'>

# %% [markdown]
# Qué pasó en el 2004 que hay ese pico?

# %% [markdown]
# Supongamos que ahora queremos lo mismo pero abierto por club. (Seleccionamos algunos porque al ser muchos clubs el gráfico no queda "bonito")

# %%
df1 = df[df.Club.isin(['FC Barcelona', 'Real Madrid', 'Leicester City', 'Napoli', 'Arsenal'])]
df1 = df1.groupby(['year_joined','Club']).agg({'Wage':'mean'}).reset_index()
sns.lineplot(data=df1, x="year_joined", y="Wage", hue="Club")
# Out:
# <AxesSubplot:xlabel='year_joined', ylabel='Wage'>

# %% [markdown]
# # Distribution

# %% [markdown]
# Ahora nos preguntamos cual es a distribución de las edades de los jugadores cuando se unen a un club. Para ver distribuciones se pueden usar varios gráficos, por ejemplo, boxplots o histogramas

# %%
sns.boxplot( y="Age",
           data=df)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.displot( df, x="Age" )

# %% [markdown]
# # Relationship

# %% [markdown]
# Si se quiere ver la correlación entre dos variables, por ejemplo entre la edad del jugador y el salario.

# %%
## scaterplot

sns.scatterplot(x="International Reputation", y="Wage",
                #palette="ch:r=-.2,d=.3_r",
                #hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=df)
# Out:
# <AxesSubplot:xlabel='International Reputation', ylabel='Wage'>

# %% [markdown]
# Qué les interesaría ver?
